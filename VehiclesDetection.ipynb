# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaledsaads/VehiclesDetection/blob/main/VehiclesDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.5/112.6 GB disk)

# %%
from ultralytics import YOLO

# %% [markdown]
# # Train YOLOv8s for Object detection

# %%
from ultralytics import YOLO
! yolo task=detect mode=train model=yolov8s.pt \
 data='/content/drive/MyDrive/ObjectDetection/VehiclesDetection/dataset.yaml'\
 imgsz= 640\
  epochs=50 batch=16\
  project= '/content/drive/MyDrive/ObjectDetection/VehiclesDetection/Training_RES'\
  name='VehiclesDetection'
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from cv2 import PCAProject
best_model = YOLO('/content/drive/MyDrive/ObjectDetection/VehiclesDetection/Training_RES/VehiclesDetection/weights/best.pt')
metrics = best_model.val()

# Or run inference on a video using these weights
results = best_model.predict(source="/content/drive/MyDrive/ObjectDetection/TestVideo/TrafficPolice.mp4",\
                             project = '/content/drive/MyDrive/ObjectDetection/TestVideo/test_vidoe_pred',\
                             name = 'video_test1',\
                             save=True)
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.7±0.3 ms, read: 23.0±3.6 MB/s, size: 32.5 KB)
# val: Scanning /content/drive/MyDrive/ObjectDetection/VehiclesDetection/Dataset/valid/labels.cache... 250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 250/250 10.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 3.1it/s 5.2s
#                    all        250        454      0.695      0.545      0.613       0.45
#              Ambulance         50         64      0.822       0.75      0.813      0.693
#                    Bus         30         46      0.724      0.696      0.706      0.571
#                    Car         90        238      0.712      0.445      0.511      0.341
# ...

# %% [markdown]
# #### Dataset + output: 'https://drive.google.com/drive/folders/1bk7FUKeH1y4cJkduXq2O63nM77y22d1Z?usp=sharing'
